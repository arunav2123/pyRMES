# %%
import matplotlib as plt
import numpy as np  
from TDRMS import TimeDependentRMS

# %%
solver = TimeDependentRMS(nt=100000, dt=0.01, NN=2**6)
solver.initialize_profiles(q0=0.8, q1=0, q2=0.8)
solver.setup_matrix()
solver.solve()
# Out:
# /Users/arunavkumar/Documents/TD_RMS/TDRMS.py:74: RuntimeWarning: divide by zero encountered in log
#   AA[it] = np.log(np.max(np.abs(psi)))
# /Users/arunavkumar/Documents/TD_RMS/TDRMS.py:75: RuntimeWarning: divide by zero encountered in log
#   AR[it] = np.log(np.max(np.abs(np.real(psi))))
# Simulation time = 67.70116806030273 sec

# %%
solver.plot_contour()
